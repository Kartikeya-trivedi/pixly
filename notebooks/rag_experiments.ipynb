# %% [markdown]
# # RAG Experiments Notebook
#
# This notebook contains experiments with the RAG (Retrieval-Augmented Generation) pipeline for Game Overlay AI.
#
# ## Experiments:
# 1. Vector database setup and testing
# 2. Embedding model comparison
# 3. Retrieval quality evaluation
# 4. LLM integration testing

# %%
# Import required libraries
import sys
import os
from pathlib import Path

# Add src to path
sys.path.insert(0, str(Path.cwd().parent / "src"))

from src.services.rag_service import RAGService
from src.services.etl_service import ETLService
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 1. Initialize RAG Service

# %%
# Initialize RAG service
rag_service = RAGService()
print("RAG service initialized successfully!")
