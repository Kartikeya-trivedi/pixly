# %% [markdown]
# # ETL Experiments Notebook
#
# This notebook contains experiments with the ETL (Extract, Transform, Load) pipeline for Game Overlay AI.
#
# ## Experiments:
# 1. Data extraction from various sources
# 2. Text preprocessing and cleaning
# 3. Document chunking strategies
# 4. Vector database ingestion
